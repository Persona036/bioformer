# %% [markdown]
# # Colab Setup
#
# Use this notebook in Google Colab to install the project, download the EFP CSV, and start training.

# %%
# !nvidia-smi

# %%
# %cd /content
# !git clone <YOUR_REPO_URL> bioformer
# %cd /content/bioformer
# !bash scripts/setup_colab.sh

# %%
# %cd /content/bioformer
# !bioformer-train-baseline --config configs/baseline.yaml

# %%
# %cd /content/bioformer
# !bioformer-train-transformer --config configs/transformer_small.yaml
